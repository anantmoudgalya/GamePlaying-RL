# %%
import numpy as np
import pandas as pd
import csv

# %%
with open("DQN_metrics.txt",'r') as f:
    lines = f.readlines()
    print(lines[0])
# Out:
#     31/50000: episode: 1, duration: 1.430s, episode steps: 31, steps per second: 22, episode reward: 31.000, mean reward: 1.000 [1.000, 1.000], mean action: 0.419 [0.000, 1.000], mean observation: 0.013 [-1.185, 1.776], loss: 0.462173, mean_absolute_error: 0.520752, mean_q: 0.096439

# %%
new_lines = []
for line in lines:
    new_lines.append(line[14:])
met_names = []
for met in new_lines[0].split(","):
    met_names.append(met.split(":")[0])
met_names
# Out:
# ['episode',
#  ' duration',
#  ' episode steps',
#  ' steps per second',
#  ' episode reward',
#  ' mean reward',
#  ' 1.000]',
#  ' mean action',
#  ' 1.000]',
#  ' mean observation',
#  ' 1.776]',
#  ' loss',
#  ' mean_absolute_error',
#  ' mean_q']

# %%
new_dict = []
for line in new_lines:
    dict_row = {}
    new_line = line.split(",")
    
    no = new_line[0].split(":")
    dict_row[no[0]] = no[1]
    
    step = new_line[2].split(":")
    dict_row[step[0]] = step[1]
    
    reward = new_line[4].split(":")
    dict_row[reward[0]] = reward[1];
    
    loss = new_line[11].split(":")
    dict_row[loss[0]] = loss[1];
    
    abs_error = new_line[12].split(":")
    dict_row[abs_error[0]] = abs_error[1];
    
    q = new_line[13].split(":")
    dict_row[q[0]] = q[1][:8];
    
    new_dict.append(dict_row)

print(new_dict)
# Out:
# [{'episode': ' 1', ' episode steps': ' 31', ' episode reward': ' 31.000', ' loss': ' 0.462173', ' mean_absolute_error': ' 0.520752', ' mean_q': ' 0.09643'}, {'episode': ' 2', ' episode steps': ' 13', ' episode reward': ' 13.000', ' loss': ' 0.350131', ' mean_absolute_error': ' 0.542971', ' mean_q': ' 0.29271'}, {'episode': ' 3', ' episode steps': ' 20', ' episode reward': ' 20.000', ' loss': ' 0.230972', ' mean_absolute_error': ' 0.559493', ' mean_q': ' 0.50141'}, {'episode': ' 4', ' episode steps': ' 19', ' episode reward': ' 19.000', ' loss': ' 0.116485', ' mean_absolute_error': ' 0.604493', ' mean_q': ' 0.83262'}, {'episode': ' 5', ' episode steps': ' 15', ' episode reward': ' 15.000', ' loss': ' 0.053599', ' mean_absolute_error': ' 0.671270', ' mean_q': ' 1.15262'}, {'episode': ' 6', ' episode steps': ' 16', ' episode reward': ' 16.000', ' loss': ' 0.036350', ' mean_absolute_error': ' 0.727577', ' mean_q': ' 1.33530'}, {'episode': ' 7', ' episode steps': ' 14', ' episode reward': ' 14.000', ' loss': ' 0.036427', ' mean_absolute_error': ' 0.768431', ' mean_q': ' 1.45269'}, {'episode': ' 8', ' episode steps': ' 23', ' episode reward': ' 23.000', ' loss': ' 0.029889', ' mean_absolute_error': ' 0.820142', ' mean_q': ' 1.60049'}, {'episode': ' 9', ' episode steps': ' 11', ' episode reward': ' 11.000', ' loss': ' 0.032700', ' mean_absolute_error': ' 0.893022', ' mean_q': ' 1.76488'}, {'episode': ' 10', ' episode steps': ' 13', ' episode reward': ' 13.000', ' loss': ' 0.052971', ' mean_absolute_error': ' 0.947109', ' mean_q': ' 1.87078'}, {'episode': ' 11', ' episode steps': ' 26', ' episode reward': ' 26.000', ' loss': ' 0.040956', ' mean_absolute_error': ' 1.002012', ' mean_q': ' 2.00596'}, {'episode': ' 12', ' episode steps': ' 58', ' episode reward': ' 58.000', ' loss': ' 0.058933', ' mean_absolute_error': ' 1.170749', ' mean_q': ' 2.31240'}, {'episode': ' 13', ' episode steps': ' 33', ' episode reward': ' 33.000', ' loss': ' 0.056220', ' mean_absolute_error': ' 1.316334', ' mean_q': ' 2.61570'}, {'episode': ' 14', ' episode steps': ' 25', ' episode reward': ' 25.000', ' loss': ' 0.066928', ' mean_absolute_error': ' 1.464536', ' mean_q': ' 2.90214'}, {'episode': ' 15', ' episode steps': ' 16', ' episode reward': ' 16.000', ' loss': ' 0.067886', ' mean_absolute_error': ' 1.546759', ' mean_q': ' 3.07470'}, {'episode': ' 16', ' episode steps': ' 33', ' episode reward': ' 33.000', ' loss': ' 0.111812', ' mean_absolute_error': ' 1.668563', ' mean_q': ' 3.20293'}, {'episode': ' 17', ' episode steps': ' 23', ' episode reward': ' 23.000', ' loss': ' 0.100669', ' mean_absolute_error': ' 1.771511', ' mean_q': ' 3.48892'}, {'episode': ' 18', ' episode steps': ' 14', ' episode reward': ' 14.000', ' loss': ' 0.082871', ' mean_absolute_error': ' 1.853316', ' mean_q': ' 3.67079'}, {'episode': ' 19', ' episode steps': ' 25', ' episode reward': ' 25.000', ' loss': ' 0.141222', ' mean_absolute_error': ' 1.945843', ' mean_q': ' 3.77181'}, {'episode': ' 20', ' episode steps': ' 46', ' episode reward': ' 46.000', ' loss': ' 0.128011', ' mean_absolute_error': ' 2.107427', ' mean_q': ' 4.11946'}, {'episode': ' 21', ' episode steps': ' 15', ' episode reward': ' 15.000', ' loss': ' 0.152254', ' mean_absolute_error': ' 2.247525', ' mean_q': ' 4.38168'}, {'episode': ' 22', ' episode steps': ' 22', ' episode reward': ' 22.000', ' loss': ' 0.133530', ' mean_absolute_error': ' 2.313178', ' mean_q': ' 4.53535'}, {'episode': ' 23', ' episode steps': ' 10', ' episode reward': ' 10.000', ' loss': ' 0.192256', ' mean_absolute_error': ' 2.424197', ' mean_q': ' 4.71486'}, {'episode': ' 24', ' episode steps': ' 38', ' episode reward': ' 38.000', ' loss': ' 0.221496', ' mean_absolute_error': ' 2.502866', ' mean_q': ' 4.85111'}, {'episode': ' 25', ' episode steps': ' 13', ' episode reward': ' 13.000', ' loss': ' 0.183715', ' mean_absolute_error': ' 2.625215', ' mean_q': ' 5.12964'}, {'episode': ' 26', ' episode steps': ' 26', ' episode reward': ' 26.000', ' loss':  ...

# %%
with open("dqn_metrics.csv", 'w') as f:
    fieldnames = ['episode', ' episode steps', ' episode reward', ' loss', ' mean_absolute_error', ' mean_q']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    
    writer.writeheader()
    for row in new_dict:
        writer.writerow(row)

# %%
df = pd.read_csv("dqn_metrics.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 6 columns):
# episode                 216 non-null int64
#  episode steps          216 non-null int64
#  episode reward         216 non-null float64
#  loss                   216 non-null float64
#  mean_absolute_error    216 non-null float64
#  mean_q                 216 non-null float64
# dtypes: float64(4), int64(2)
# memory usage: 10.2 KB
